# %% [markdown]
# # IST736 Text Mining
# ## Homework 3
# ### Martin Alonso
# ### 2019-01-31

# %% [markdown]
# #### Objectives
# For this assignment, I will be creating a text corpus based on the work of my friend Russell Carlton. With his permission, I have downloaded nine articles he has written over the past decade for the website Baseball Prospectus, where he writes about baseball from an analytical point of view while relying heavily on the statistical and psychological side of the sport.
# The corpus will be created using the NLTK package and, after creation, I will vectorize the documents and explore any trends that may appear over his work.

# %% [markdown]
# #### Analysis
#
# ##### Loading the packages and creating the corpus
# I'll first load the packages that will be used, starting with NLTK, Pandas, and Numpy. I'll also load Matplotlib and Seaborn for graphing the corpus.

# %%
# Packages to be used.
import os
import nltk
from nltk.corpus import stopwords
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
import re 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator
import collections

# Downloads nltk packages
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\malon\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\malon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\malon\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Now that the packages have been loaded, I'll use NLTK's PlaintextCorpusReader to load the text files into Python. Once these texts are loaded, a new corpus can be created using the nine documents. These can then be analyzed as words, sentences, paragraphs, or as a whole.

# %%
# Designate the folder directory where the texts are located and load them into the notebook. 
# Sets the directory where the files are stored for easy acces. 
corpus_dir = 'Corpus/'

# Passes the files in the directory into a new corpus that can then be parsed and studied. 
new_corpus = PlaintextCorpusReader(corpus_dir, '.*')

# %%
# Creates an array where the file names are stored for easy access. 
texts = []
for file in os.listdir(corpus_dir):
    texts.append(file)
    
print(texts)
# Out:
# ['Russel1.txt', 'Russel2.txt', 'Russel3.txt', 'Russel4.txt', 'Russel5.txt', 'Russel6.txt', 'Russel7.txt', 'Russel8.txt', 'Russel9.txt']

# %%
# Creates two empty arrays that will store word counts and words for each text in the corpora. 
word_counts = []
word_corpus = []

# Iterates over every item in the texts array to print the word count of each text in the corpora. 
for file in texts:
    file_length = len(new_corpus.words(file))
    words = new_corpus.words(file)
    word_counts.append(file_length)
    word_corpus = np.concatenate([word_corpus, words]) # Word corpus needs to be concatenated, otherwise a list is created. 
    print(file, ': %d' % file_length)
    
# Prints the average number of words across the corpora. 
print('Avg Word Count: %d' % np.mean(word_counts))
print('Total Word Count: %d' % len(word_corpus))
# Out:
# Russel1.txt : 1496
# Russel2.txt : 2328
# Russel3.txt : 960
# Russel4.txt : 2276
# Russel5.txt : 2537
# Russel6.txt : 1847
# Russel7.txt : 4430
# Russel8.txt : 4438
# Russel9.txt : 1784
# Avg Word Count: 2455
# Total Word Count: 22096

# %% [markdown]
# A few interesting things to note before we move on. First off, there are over 22,000 words in these nine documents, including stop words. The average number of words is 2,455, though the data set may be slightly skewed on account of there being to texts with word counts over 4,400. The smallest, or briefest, text has only 960 words.
#
# Now that the documents have been loaded, the corpus has been created and we know how many words there are in total, we can begin to analyze the corpus. First of, English stop words will be removed; after that, the remaining words in the corpus will be vectorized and stemmed.
# To begin, let's check the list of the most common words in the corpus.

# %%
# Initialize a dictionary. 
wordcount = {}

# Iterate over the word corpus to remove special characters that may muddy the data. 
for word in word_corpus:
    word = re.sub('[\W\_]', '', word).lower()
    if word not in wordcount:
        wordcount[word] = 1
    else:
        wordcount[word] += 1

# Because special characters have been replaced with '', '' will need to be removed from the wordcount
# dictionary so as to not skew the data.
wordcount.pop('', None)

# Print the 20 most common words. 
n_print = 20            
word_counter = collections.Counter(wordcount)
for word, count in word_counter.most_common(n_print):
    print(word, ": %d" % count)

# Create a data frame of the most common words 
# Draw a bar chart
lst = word_counter.most_common(n_print)
df = pd.DataFrame(lst, columns = ['Word', 'Count'])
df.plot.bar(x='Word',y='Count')
# Out:
# the : 1089
# a : 526
# to : 503
# that : 477
# of : 418
# and : 314
# in : 304
# it : 268
# is : 216
# s : 210
# for : 205
# i : 188
# we : 165
# but : 150
# on : 145
# you : 145
# t : 118
# at : 117
# be : 115
# are : 113

# %% [markdown]
# Of course, this is cheating. No stop words have been removed from the data set, skewing the corpus word frequency. 'The' is used over one thousand times across the entire corpus, along with 'a', 'to', 'that', and so forth. If we were to remove stop words from this dictionary, the term frequency would be vastly different. Let's check word frequency after removing stop words.

# %%
# Initiate English stop words
stop = stopwords.words('english')

wordcount2 = wordcount

for s in stop: 
    wordcount2.pop(s, None)
    
# Print the 20 most common words. 
n_print = 20       
word_counter = collections.Counter(wordcount2)
for word, count in word_counter.most_common(n_print):
    print(word, ": %d" % count)

# Create a data frame of the most common words 
# Draw a bar chart
lst = word_counter.most_common(n_print)
df = pd.DataFrame(lst, columns = ['Word', 'Count'])
df.plot.bar(x='Word',y='Count')
# Out:
# would : 75
# game : 69
# shift : 69
# first : 65
# time : 64
# one : 60
# players : 58
# get : 51
# games : 49
# might : 48
# balls : 46
# 5 : 44
# baseball : 43
# going : 41
# 1 : 41
# ball : 41
# play : 40
# see : 39
# even : 38
# like : 37

# %% [markdown]
# With stop words removed, there are much better results. But there is still room for improvement. For example, the numbers 5 and 1 appear in the most frequent words. Number shoud either be changed or be removed as they can give us unwanted results. We also see that both balls and ball appear in the top 20; meaning that stemming should be the next natural process before moving on with analyzing the corpus.
#
# Because we are working with multiple documents, we'll revert to the original texts and build a TF-IDF vectorizer for each document using lemmatization and removing stop words, special characters, and numbers not written out.

# %%
# A new array will be initiated from scratch. 
corpora = []

# Insert each file into the corpora array. 
for file in texts:
    corpus = new_corpus.raw(file)
    corpora.append(corpus)

# %% [markdown]
# With the corpora built once again, it is time to clean the texts and vectorize them. We'll first lemmatize the text, then remove special character, numbers and stop words.

# %%
# Lemmatization of the corpora to group words. 
lemmatizer = WordNetLemmatizer()

# Define the lemmatizer so it can be inserted into the TF-IDF tokenizer
def lemm_words(doc):
    return (lemmatizer.lemmatize(w) for w in vectorizer(doc))

# Initialize vectorizer. The tokenizer is first built and then the corpora is parsed through the lemmaitized tokenizer. 
vectorizer = TfidfVectorizer(token_pattern='[^\W\_\0-9]+', stop_words='english').build_tokenizer()
tf_lemm = TfidfVectorizer(tokenizer=lemm_words, token_pattern='[^\W\_\0-9]+', stop_words='english', min_df=0.2, max_df=5,  
                          analyzer='word', max_features=500)
results = tf_lemm.fit_transform(corpora)

# Prints shape of the results. 
print(results.shape)
# Out:
# (9, 500)
# C:\Users\malon\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %% [markdown]
# #### Results
#
# Now that the tokenizer has been built, let's check the results for the most common words featured in this corpus, and build a word cloud to understand which are the 500 most common words of this sample.

# %%
# Build data frames to store words and TF-IDF results
words, values = pd.DataFrame(np.array(tf_lemm.get_feature_names())), pd.DataFrame(np.array(results.mean(axis=0))).transpose()

# Build a dataframe with the words and tf-idf results to view words with both the highest and lowest scores. 
final_results = pd.concat([words, values], axis=1)
final_results.columns = ['words', 'tf-idf']
final_results = final_results.sort_values(by=['tf-idf'], ascending=False)
print('Top 10 highest frequency: ') 
print(final_results.iloc[:10, :], '\n')

print('Bottom 10 lowest frequency: ')
print(final_results.iloc[489:, :])
# Out:
# Top 10 highest frequency:
#            words    tf-idf
# 43          ball  0.158654
# 162      fielder  0.092757
# 326        pitch  0.084625
# 327      pitcher  0.080678
# 61          blue  0.079738
# 188        group  0.070448
# 315      percent  0.068675
# 293            n  0.066348
# 465       voting  0.061962
# 356  replacement  0.061329
#
# Bottom 10 lowest frequency:
#            words    tf-idf
# 398       spread  0.004693
# 58        binary  0.004423
# 75   calculating  0.004423
# 415       strong  0.004423
# 408        stats  0.004423
# 445      totally  0.004423
# 242        large  0.003858
# 55       benefit  0.003858
# 189      growing  0.003858
# 26    approached  0.003858
# 217      imagine  0.003858

# %% [markdown]
# Given that these are baseball articles, it makes sense that the most common words, or rather the most weight is attributed, are those that reflect upon baseball itself. Words like 'ball', 'fielder', 'pitch', 'pitcher' are heavily presented. However, given the nature of these texts as being very analytical, it also makes sense that words like 'group', 'percent', and 'n' as these are part of the scientific vernacular.
# On the other end, there are words that don't really add much to the text and don't give us much idea as to what these texts are about. Nevertheless, they are important enough to be included among the 500 most influential words as deemed by the tokenizer.
# Before we move on to our conclusions, let's take a look at the word cloud for this tokenizer.

# %%
# Create a dictionary with the words and TF-IDF values that will be passed into WordCloud()
d = {}
for a, x in final_results.values:
    d[a] = x

# Adjust image parameters to increase height and width of figure, create word cloud, and show image
plt.rcParams['figure.figsize'] = [10, 5]
wordcloud = WordCloud(scale=5)
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# #### Final thoughts and conclusions
#
# Choosing nine texts to feature as part of the corpora was not that difficult. What was difficult was parsing them and then understanding how to work them into the vectorizer, taking into account lemmatization, stop words, special characters, and numbers. Having done this initial exercise, I believe it would be very interesting and worthwhile to increase the corpora and evaluate how the results change.
# Mr. Carlton is a good friend of mine and I appreciate him granting me permission to work on his texts. Given his penchant for analysis of baseball on both the numeric and human side of the game, I can say that the results, though not what I expected, were almost close to the mark.
